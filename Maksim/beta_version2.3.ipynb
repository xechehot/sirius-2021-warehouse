# %% [markdown]
# <a href="https://colab.research.google.com/github/xechehot/sirius-2021-warehouse/blob/main/Maksim/beta_version2.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_dist_for_1_path(sx, sy, block, data_for_ans): #data_for_ans - для ячейки храним какой заказ в ней
    x = sx
    y = sy
    dist = 0
    ans = []
    d = -1
    N = len(block)
    M = len(block[0])
    if (sy == 0): d = 1
    end = -1
    if (d == -1):
        for i in range(M):
            if (block[:, i].sum() == 0):
                end = i
            else: break
    else:
        for i in range(M - 1, -1, -1):
            if (block[:, i].sum() == 0):
                end = i
            else: break
    while True:
        if x < 0 or y < 0 or x >= N or y >= M or y == end: break
        if (block[:, y].sum() == 0):
            dist += 2
            y += d
            continue
        if x == N - 1: #идем вверх
            for nx in range(N - 1, -1, -1):
                if block[nx][y] != 0: 
                    ans.append(data_for_ans[nx][y])
        else: # идем вниз
            for nx in range(0, N):
                if (block[nx][y] != 0):
                    ans.append(data_for_ans[nx][y])
        dist += N
        dist += 2
        x = abs(x - (N - 1))
        y += d
    dist -= 2

    #if x == N - 1: dist += N
    return [get_normal_dist(ans), ans]

# %%
def get_next(places):
    for _ in range(3):
        i = rand(0, len(places) - 1)
        j = rand(0, len(places) - 1)
        if i == j:
            i = rand(0, len(places) - 1)
            j = rand(0, len(places) - 1)
        if i == j:
            i = rand(0, len(places) - 1)
            j = rand(0, len(places) - 1)
        if i > j: i, j = j, i
        if i != 0: places[i:j + 1] = places[j:i - 1:-1]
        else: places[i:j + 1] = places[j::-1]
        #places[i], places[j] = places[j], places[i]
    return places

def get_dist_with_annealing(places):
    t = 1
    dist = get_normal_dist(places)
    cnt = 0
    for _ in range(1000):
        new = get_next(places[::])
        new_dist = get_normal_dist(new)
        if (new_dist < dist):
            dist = new_dist
            places = new
        elif (new_dist > dist):
            #print(math.exp((dist - new_dist) / t))
            if (math.exp((dist - new_dist) / t) > rand(0, 10**6) / 10**6):
                places = new
                dist = new_dist
        t = t * 0.99
    return [dist, places]

# %%
from random import randint as rand
import numpy
import json
import math

# %%
! git clone https://github.com/xechehot/sirius-2021-warehouse.git
# Out:
# fatal: destination path 'sirius-2021-warehouse' already exists and is not an empty directory.

# %%
! cd sirius-2021-warehouse; git pull
# Out:
# Already up to date.

# %%
rows = sample_data['warehouse']['meta']['rows']
sections = sample_data['warehouse']['meta']['sections']
block_x = sample_data['warehouse']['meta']['block_x']
block_y = sample_data['warehouse']['meta']['block_y']
floors = sample_data['warehouse']['meta']['floors']
batch = sample_data['batch_size']
b_sz = 32
N = rows // 2 + 1
M = sections + 1

# %%
def get_places(cnt_products, product_place): #ищу ячейки, куда нужно зайти
    ans = []
    for id in product_set:
        product_place[id].sort(key = lambda a: -block_popular[a['p']['floor'] - 1][get_place_block(a['p'])]) #????????
    for id in product_set:
        have = cnt_products[id]
        ind = 0
        while (have > 0 and ind < len(product_place[id])):
            sample_data['warehouse']['stock'].remove(product_place[id][ind])
            if (product_place[id][ind]['count'] >= have):
                ans.append([product_place[id][ind]['p'], have, id])
                product_place[id][ind]['count'] -= have
                sample_data['warehouse']['stock'].append(product_place[id][ind])
                have = 0
            else:
                ans.append([product_place[id][ind]['p'], product_place[id][ind]['count'], id])
                have -= product_place[id][ind]['count']
            ind += 1
    return ans

# %%
def distribute_data(places): #разделяю ячейки по этажам, блокам 
    ans = [[[[] for i1 in range(block_y)] for i2 in range(block_x)] for i3 in range(floors)]
    for place in places:
        ans[place[0]['floor'] - 1][place[0]['block_x'] - 1][place[0]['block_y'] - 1].append(place)
    return ans

# %%
def conv_place(place):
    return [place['row'] // 2, place['section']]

# %%
def dist_to_start(place): 
    ans = 0
    dy = int(abs(block_y // 2 + 0.5 - place['block_y']) + 0.5) - 1
    ans += dy * (rows + 2) #расстояние по горизонтали к центру
    ans += (block_x - place['block_x']) * (sections + 2) #расстояние по вертикали к низу
    if (place['block_y'] <= block_y // 2): ans += (rows - place['row']) #расстояние внутри блока
    else: ans += place['row']
    ans += (sections + 1 - place['section'])
    return ans

# %%
def dist_to_tape(place):
    ans = place['section'] + (place['block_x'] - 1) * (sections)
    return ans

# %%
def get_ans_for_1_block(data, sx, sy):
    block = numpy.zeros((N, M), int)
    list_of_products = [[-1 for i in range(M)] for j in range(N)]
    #print(data)
    bx, by = -1, -1
    for place, cnt, id in data:
        x, y = conv_place(place)
        bx = place['block_x']
        by = place['block_y']
        block[x, y] += cnt
        list_of_products[x][y] = [place, cnt, id]
    s_dist, s_paths = get_dist_for_1_path(sx, sy, block, list_of_products)
    dist, paths = get_dist_with_annealing(s_paths)
    ans = []
    cur = []
    sum = 0
    #print(paths)
    for place, cnt, id in paths:
        if (sum + cnt <= 32):
            cur.append([place, cnt, id])
            if sum == 0:
                dist += dist_to_start(place)
            sum += cnt
        else:
            exist = cnt
            while exist > 0:
                now = min(exist, 32 - sum)
                cur.append([place, now, id])
                if sum == 0:
                    dist += dist_to_start(place)
                sum += now
                exist -= now
                if (sum == 32):
                    dist += dist_to_tape(place) * 2
                    dist += dist_to_start(place)
                    ans.append(cur)
                    cur = []
                    sum = 0
        if (sum == 32):
            dist += dist_to_tape(place) * 2
            dist += dist_to_start(place)
            ans.append(cur)
            cur = []
            sum = 0
    if (cur != []):
        dist += dist_to_tape(cur[-1][0]) * 2
        dist += dist_to_start(cur[-1][0])
        ans.append(cur)
        cur = []
        sum = 0
    return [ans, dist]

# %%
    def get_dist_2_places(p1, p2):
        ans = 0
        if p1['block_x'] != p2['block_x'] or p1['block_y'] != p2['block_y'] or p1['row'] != p2['row']:
            if p1['block_x'] > p2['block_x']: p1, p2 = p2, p1
            if p1['block_x'] != p2['block_x']:
                ans += (p2['block_x'] - p1['block_x'] - 1) * sections
            ans += (p2['block_x'] - p1['block_x']) * 2 - 1
            ans += min(p1['section'] + p2['section'], 2 * sections - p1['section'] - p2['section'] + 2)
            if p1['block_y'] > p2['block_y']: p1, p2 = p2, p1
            ans += (rows - p1['row'] + 1) + p2['row']
            if p1['block_y'] != p2['block_y']:
                ans += (p2['block_y'] - p1['block_y'] - 1) * rows
            ans += (p2['block_y'] - p1['block_y']) * 2 - 1
            return ans
        else:
            return abs(p1['section'] - p2['section'])

# %%
def get_path_len(path):
    ans = 0
    for place, cnt, _ in path:
        ans += cnt
    return ans

def get_ans_for_1_floor(paths): # возвращает пару ответ и изменение dist
    delta = 0
    res = []
    ans = [[] for i in range(block_x * block_y)]
    for path in paths:
        if (get_path_len(path) == 32):
            res.append(path)
            continue
        num = (path[0][0]['block_x'] - 1) * block_y
        if path[0][0]['block_x'] == 1: num += path[0][0]['block_y'] - 1
        else: num += (block_y - path[0][0]['block_y'])
        ans[num] = path
    last = []
    for path in ans:
        if path == []: continue
        if last == []:
            last = path
        else:
            if (get_path_len(last) + get_path_len(path) <= 32):
                add = get_dist_2_places(last[-1][0], path[0][0])
                sub = dist_to_start(last[-1][0]) + dist_to_start(path[0][0]) + dist_to_tape(last[-1][0]) * 2
                if (add < sub):
                    delta += add
                    delta -= sub
                    for elem in path: last.append(elem)
                else:
                    res.append(last)
                    last = path
            else:
                res.append(last)
                last = path
    if (last != []): res.append(last)
    return [res, delta]

# %%
product_place = {}
cnt_products = {}
product_set = set()
super_block = 0
super_floor = 0
block_popular = [[0 for i in range(block_x * block_y)] for j in range(floors)]

# %%
def prepair_product_place():
    for product in sample_data['warehouse']['stock']:
        if product_place.get(product['id']) == None:
            product_place[product['id']] = []
        product_place[product['id']].append(product)
def prepair_cnt_products():
    for i in range(min(len(sample_data['orders']), batch)):
        order = sample_data['orders'][0]
        sample_data['orders'].pop(0)
        for product in order['items']:
            product_set.add(product['id'])
            if (cnt_products.get(product['id']) == None):
                cnt_products[product['id']] = 0
            cnt_products[product['id']] += product['count']

# %%
def get_normal_dist(path):
    ans = 0
    ans += dist_to_start(path[0][0]) + dist_to_start(path[-1][0])
    ans += dist_to_tape(path[-1][0]) * 2
    for i in range(len(path) - 1):
        ans += get_dist_2_places(path[i][0], path[i + 1][0])
    return ans

# %%
def get_where_exist(order):
    cnt1 = 0
    cnt2 = 0
    for product in order:
        place = product_place[product['id']][0]
        if (place['p']['block_y'] <= block_y // 2):
            cnt1 += product['count']
        cnt2 += product['count']
    return cnt1 / cnt2
def exist_in_most_popular_block(order):
    cnt1 = 0
    cnt2 = 0
    for product in order:
        sum = 0
        for place in product_place[product['id']]:
            if place['p']['floor'] - 1 == super_floor and get_place_block(place['p']) == super_block:
                sum += place['count']
        cnt1 += min(product['count'], sum)
        cnt2 += product['count']
    return -cnt1 / cnt2

def sort_orders():
    sample_data['orders'].sort(key = lambda x: exist_in_most_popular_block(x['items']))

# %%
def get_place_block(place):
    return (place['block_x'] - 1) * block_y + place['block_y'] - 1

def count_blocks_popular():
    global super_floor, super_block
    for order in sample_data['orders']:
        cnt2 = 0
        for product in order['items']:
            cnt2 += product['count']
        for product in order['items']:
            for place in product_place[product['id']]:
                block_popular[place['p']['floor'] - 1][get_place_block(place['p'])] += min(place['count'], product['count']) / cnt2
                if (block_popular[place['p']['floor'] - 1][get_place_block(place['p'])] > block_popular[super_floor][super_block]):
                    super_floor = place['p']['floor'] - 1
                    super_block = get_place_block(place['p'])

# %%
with open('sirius-2021-warehouse/data_sample/sample_3200_4.json') as f:
    sample_data = json.load(f)

# %%
with open('sirius-2021-warehouse/data_sample/sample_3200_4.json') as f:
    sample_data = json.load(f)
sum_dist = 0
cnt = 0
for order in sample_data['orders']:
    for product in order['items']:
        cnt += product['count']

g_ans = []
for i in range((len(sample_data['orders']) - 1) // batch + 1):
    cnt_products = {}
    product_set = set()
    product_place = {}
    block_popular = [[0 for i in range(block_x * block_y)] for j in range(floors)]
    prepair_product_place()
    super_block = 0
    super_floor = 0
    count_blocks_popular()
    #print(super_block, super_floor)
    sort_orders()
    prepair_cnt_products()
    #print(block_popular[super_floor][super_block])
    #print(block_popular)
    #break
    #print(block_popular)
    places = get_places(cnt_products, product_place)
    dis = distribute_data(places)
    dist = 0
    ans_for_floors = [[] for i in range(floors)]
    for floor in range(floors):
        for bx in range(block_x):
            for by in range(block_y):
                if (dis[floor][bx][by] == []): continue
                sx = N - 1
                if (by >= 2): sx = 0
                p_ans, p_dist = get_ans_for_1_block(dis[floor][bx][by], sx, 0)
                dist += p_dist
                for elem in p_ans: 
                    ans_for_floors[floor].append(elem)
    ans = []
    for i in range(floors):
        p_ans, delta = get_ans_for_1_floor(ans_for_floors[i])
        for elem in p_ans: ans.append(elem)
        dist += delta
    #print(dist, delta)
    dist_ans = 0
    for path in ans:
        dist_ans += get_normal_dist(path)
    #print(ans)
    #print(dist_ans)
    sum_dist += dist_ans
    g_ans.append(ans)
print(sum_dist / cnt)
# Out:
# 10.020032051282051

# %%
output = {
    "batches": [
                
    ]
}

# %%
for ans in g_ans:
    buckets = []
    for bucket in ans:
        for item in bucket:
            out
            print(item)
# Out:
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 20, 'section': 12}, 3, 12994285]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 11, 'section': 6}, 1, 10197991]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 11, 'section': 14}, 2, 8607062]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 13, 'section': 15}, 2, 81786000]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 13, 'section': 11}, 1, 15049951]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 9, 'section': 12}, 2, 64125894]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 9, 'section': 2}, 1, 5277987]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 8, 'section': 6}, 1, 13674608]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 4}, 2, 91695805]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 16}, 1, 9010088]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 9}, 1, 44389563]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 10}, 1, 89674946]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 6}, 11, 94911780]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 20}, 3, 29133818]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 20}, 1, 29133818]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 1, 'section': 10}, 1, 69379980]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 1, 'section': 5}, 1, 5833320]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 2, 'section': 11}, 4, 72657454]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 15, 'section': 11}, 1, 73035776]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 15, 'section': 1}, 14, 81637577]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 16, 'section': 13}, 3, 16728016]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 16, 'section': 16}, 1, 78999968]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 16, 'section': 11}, 1, 71419895]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 14, 'section': 8}, 1, 50519630]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 14, 'section': 9}, 1, 92135801]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 12, 'section': 20}, 1, 59652449]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 12, 'section': 7}, 1, 33020891]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 18, 'section': 6}, 1, 94822841]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 18, 'section': 4}, 1, 15891385]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 18, 'section': 8}, 1, 25049943]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 7, 'section': 18}, 14, 15049951]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 3, 'section': 19}, 1, 28878737]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 3, 'section': 14}, 5, 28235691]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 3, 'section': 10}, 2, 1295787]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 3, 'section': 9}, 1, 40814790]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 18}, 1, 44336477]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 15, 'section': 20}, 1, 29147154]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 15, 'section': 13}, 1, 49220025]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 8, 'section': 17}, 1, 68542596]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 6, 'section': 20}, 1, 66422708]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 6, 'section': 11}, 8, 85309557]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 6, 'section': 9}, 1, 84881051]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 19, 'section': 8}, 3, 9275683]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 3, 'section': 8}, 1, 9284293]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 5}, 1, 64125894]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 6}, 3, 57672161]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 10, 'section': 14}, 1, 16160035]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 10, 'section': 6}, 4, 63327350]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 13, 'section': 6}, 5, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 13, 'section': 6}, 17, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 2, 'section': 2}, 2, 37364473]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 19, 'section': 1}, 1, 75195966]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 2}, 4, 20439990]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 16, 'section': 4}, 8, 44461481]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 16, 'section': 1}, 1, 35655923]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 18, 'section': 3}, 3, 81522366]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 18, 'section': 9}, 8, 65538728]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 18, 'section': 10}, 1, 11369612]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 14, 'section': 5}, 5, 60108367]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 7, 'section': 5}, 4, 88404297]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 2}, 1, 35871585]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 20, 'section': 1}, 2, 36615030]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 20, 'section': 13}, 2, 77728197]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 9}, 1, 1123935]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 14}, 1, 69914306]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 15}, 1, 87554381]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 9, 'section': 16}, 2, 7170281]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 9, 'section': 6}, 1, 53649388]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 9, 'section': 10}, 1, 5691554]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 18, 'section': 17}, 1, 79271224]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 18, 'section': 10}, 1, 93097139]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 18, 'section': 13}, 1, 41531549]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 12}, 1, 56918577]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 6}, 2, 40530953]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 5}, 6, 94948127]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 3, 'section': 1}, 1, 72540598]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 15, 'section': 5}, 2, 5833320]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 19, 'section': 1}, 12, 16728016]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 2}, 2, 55532638]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 5}, 2, 9905776]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 8}, 1, 62583828]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 19}, 2, 37114023]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 14, 'section': 11}, 6, 75064794]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 13, 'section': 15}, 1, 42819893]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 18}, 1, 899512]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 14}, 1, 36857268]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 10, 'section': 14}, 3, 1620399]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 2, 'section': 8}, 1, 10832934]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 2, 'section': 9}, 1, 5277987]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 2, 'section': 4}, 2, 57755864]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 7, 'section': 2}, 1, 92730155]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 9, 'section': 12}, 1, 99560397]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 20}, 1, 4338031]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 4, 'section': 9}, 1, 45639563]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 17, 'section': 1}, 2, 59995924]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 16, 'section': 10}, 2, 31966455]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 6, 'section': 19}, 1, 52602448]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 1, 'section': 12}, 1, 41221593]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 1, 'section': 16}, 3, 85502361]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 10}, 1, 88957714]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 8}, 2, 39652750]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 15}, 6, 70068215]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 12, 'section': 17}, 1, 63346154]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 1, 'section': 10}, 1, 54446156]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 16, 'section': 2}, 1, 5238420]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 16, 'section': 12}, 10, 92277776]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 5, 'section': 13}, 2, 41221593]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 10, 'section': 14}, 1, 90824067]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 10, 'section': 19}, 3, 12804031]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 13, 'section': 13}, 1, 67247478]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 13, 'section': 7}, 1, 89992783]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 17, 'section': 4}, 2, 12994285]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 17, 'section': 4}, 1, 12994285]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 11}, 1, 84812752]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 6}, 1, 87554381]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 15, 'section': 20}, 10, 2329890]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 15, 'section': 12}, 7, 9275683]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 8, 'section': 19}, 1, 54115880]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 8, 'section': 2}, 1, 65702190]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 1}, 1, 21706181]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 11, 'section': 2}, 1, 19979711]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 11, 'section': 6}, 2, 82634601]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 11, 'section': 13}, 1, 58925735]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 7, 'section': 12}, 2, 88025244]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 7, 'section': 2}, 1, 31534336]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 7, 'section': 19}, 1, 55190446]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 2, 'section': 20}, 1, 36857268]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 19, 'section': 5}, 1, 13814793]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 19, 'section': 12}, 1, 69558272]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 19, 'section': 1}, 3, 95066724]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 9}, 10, 41898450]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 2}, 3, 51261737]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 18, 'section': 18}, 3, 14178768]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 10, 'section': 16}, 2, 39678721]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 2, 'section': 15}, 1, 88924906]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 14, 'section': 20}, 1, 54890801]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 14, 'section': 6}, 2, 80788144]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 2}, 8, 93783328]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 14}, 4, 41018725]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 1, 'section': 14}, 2, 37364473]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 18}, 6, 51525935]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 17}, 1, 18451055]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 15}, 1, 96514301]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 6}, 1, 41909773]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 17, 'section': 7}, 1, 18035878]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 17, 'section': 13}, 1, 97226627]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 19, 'section': 3}, 1, 93999221]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 8}, 1, 40246342]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 13}, 1, 16258010]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 7}, 1, 72545784]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 2}, 1, 99560397]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 13, 'section': 1}, 25, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 13, 'section': 1}, 24, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 7, 'section': 10}, 2, 36350522]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 7, 'section': 14}, 1, 59402502]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 7, 'section': 4}, 1, 63250105]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 16, 'section': 1}, 1, 2705365]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 9, 'section': 10}, 1, 41678893]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 6, 'section': 1}, 2, 156240]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 6, 'section': 13}, 2, 82850554]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 6, 'section': 17}, 1, 57265309]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 3, 'section': 14}, 1, 31966455]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 3, 'section': 20}, 1, 76188854]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 8, 'section': 13}, 1, 82329698]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 4, 'section': 13}, 1, 78740891]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 3, 'section': 2}, 1, 96682073]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 2, 'section': 16}, 1, 19005313]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 15, 'section': 12}, 2, 66033624]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 15, 'section': 5}, 12, 84637784]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 13, 'section': 14}, 3, 32756128]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 3, 'section': 12}, 1, 81981026]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 3, 'section': 17}, 1, 41909773]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 3, 'section': 4}, 1, 28277611]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 3, 'section': 2}, 2, 93641661]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 6, 'section': 6}, 2, 38607496]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 6, 'section': 20}, 2, 29133818]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 19, 'section': 14}, 1, 13800244]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 1, 'section': 20}, 1, 58266902]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 1, 'section': 2}, 1, 85601002]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 19, 'section': 6}, 1, 59168144]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 11, 'section': 3}, 1, 78333546]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 11, 'section': 3}, 1, 78333546]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 11, 'section': 13}, 1, 93097139]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 2, 'section': 19}, 11, 59129182]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 18}, 1, 95066724]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 17}, 1, 9234779]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 5}, 3, 36269199]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 4}, 2, 23592733]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 7, 'section': 5}, 2, 22492248]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 7, 'section': 3}, 1, 99936823]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 2, 'section': 6}, 2, 60802704]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 2, 'section': 5}, 1, 96514301]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 2, 'section': 20}, 4, 77048128]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 20, 'section': 18}, 2, 65538728]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 20, 'section': 18}, 4, 65538728]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 10, 'section': 16}, 1, 2705365]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 10, 'section': 12}, 2, 68695025]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 16, 'section': 12}, 10, 75064794]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 16, 'section': 20}, 1, 11608064]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 12, 'section': 9}, 1, 44127242]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 12, 'section': 10}, 5, 60161867]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 1, 'section': 15}, 3, 67622656]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 17, 'section': 9}, 1, 58317664]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 17, 'section': 7}, 1, 72691990]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 5, 'section': 2}, 3, 90915931]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 15, 'section': 7}, 1, 39410594]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 9}, 2, 99602766]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 19, 'section': 7}, 1, 9339930]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 6, 'section': 16}, 1, 67796388]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 9}, 1, 67477573]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 2, 'section': 2}, 1, 10832934]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 16, 'section': 18}, 2, 15026215]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 16, 'section': 17}, 1, 11488907]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 19, 'section': 14}, 2, 87515631]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 15, 'section': 5}, 4, 70412303]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 15, 'section': 7}, 6, 39410594]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 15, 'section': 10}, 1, 4747578]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 8, 'section': 15}, 1, 41831030]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 18, 'section': 16}, 1, 63861922]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 4, 'section': 19}, 1, 15581599]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 4, 'section': 11}, 1, 70239346]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 9, 'section': 13}, 1, 21828161]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 7, 'section': 18}, 1, 31534336]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 7, 'section': 9}, 1, 73035776]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 17, 'section': 7}, 1, 61602178]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 8, 'section': 2}, 3, 80529755]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 8, 'section': 11}, 1, 46626108]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 9}, 4, 99602766]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 11}, 1, 13791091]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 2}, 1, 34406583]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 3}, 1, 47450467]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 3, 'section': 8}, 1, 30131113]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 3, 'section': 7}, 2, 37105999]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 3, 'section': 5}, 3, 94458446]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 6, 'section': 3}, 2, 25847751]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 6, 'section': 17}, 2, 88025244]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 20}, 1, 54383436]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 12}, 18, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 12}, 3, 24950791]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 15}, 1, 46125233]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 11}, 1, 13504203]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 5}, 2, 23709986]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 14, 'section': 1}, 12, 86959534]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 1, 'section': 7}, 1, 44461481]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 11, 'section': 10}, 3, 4281619]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 2, 'section': 20}, 2, 50187205]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 5, 'section': 12}, 3, 9339930]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 13, 'section': 20}, 1, 95409067]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 13, 'section': 12}, 3, 67796388]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 13, 'section': 4}, 1, 31804599]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 5, 'section': 6}, 2, 80759113]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 10}, 1, 45361847]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 4, 'section': 15}, 5, 64596561]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 17, 'section': 17}, 1, 39652750]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 2, 'section': 18}, 1, 88070992]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 8, 'section': 9}, 1, 89968141]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 3, 'section': 5}, 1, 35040309]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 1}, 4, 67622656]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 10, 'section': 9}, 1, 52230841]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 7}, 1, 75349692]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 19, 'section': 12}, 1, 15322184]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 19, 'section': 17}, 3, 60108367]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 19, 'section': 9}, 10, 83590010]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 19, 'section': 1}, 10, 53520152]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 19, 'section': 18}, 2, 70990412]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 1, 'section': 18}, 1, 44481220]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 1, 'section': 17}, 1, 9854735]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 9, 'section': 18}, 1, 48702896]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 9, 'section': 3}, 2, 22575508]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 16, 'section': 8}, 1, 28457329]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 16, 'section': 4}, 2, 58223172]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 16, 'section': 2}, 2, 30932737]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 3, 'section': 4}, 4, 81129793]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 3, 'section': 16}, 1, 91695805]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 3, 'section': 20}, 1, 97572682]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 1, 'section': 20}, 2, 78524267]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 17, 'section': 16}, 1, 63320584]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 20, 'section': 18}, 1, 25203716]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 11, 'section': 11}, 6, 25955065]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 17, 'section': 1}, 2, 50187205]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 17, 'section': 6}, 1, 838352]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 12, 'section': 7}, 1, 83042658]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 12, 'section': 6}, 1, 93414863]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 10, 'section': 4}, 2, 73195220]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 10, 'section': 6}, 1, 43259901]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 6, 'section': 3}, 1, 98878242]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 18, 'section': 11}, 1, 70740386]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 2, 'section': 15}, 2, 20098592]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 13, 'section': 20}, 1, 5146455]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 1, 'section': 19}, 1, 50001986]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 11, 'section': 17}, 1, 44190408]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 14, 'section': 12}, 1, 11458449]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 7, 'section': 20}, 2, 88906902]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 14, 'section': 17}, 3, 22575508]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 6, 'section': 15}, 1, 59399069]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 15, 'section': 13}, 1, 36269199]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 15, 'section': 2}, 1, 3576599]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 4, 'section': 9}, 2, 52154171]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 5, 'section': 10}, 1, 12830875]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 5, 'section': 7}, 1, 69896673]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 10, 'section': 20}, 1, 54383436]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 4, 'section': 14}, 1, 4243905]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 4, 'section': 19}, 1, 15581599]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 1, 'section': 9}, 1, 22701415]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 14, 'section': 1}, 1, 86959534]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 4}, 1, 90905519]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 11, 'section': 15}, 2, 40210200]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 11}, 1, 20392982]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 7}, 1, 72545784]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 4, 'section': 6}, 1, 72797630]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 7}, 2, 457333]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 16, 'section': 14}, 1, 43377462]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 12, 'section': 17}, 1, 63346154]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 12, 'section': 4}, 1, 34079424]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 7, 'section': 2}, 1, 31534336]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 20, 'section': 11}, 2, 53947195]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 6, 'section': 14}, 2, 82408055]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 6, 'section': 3}, 1, 84812752]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 1}, 2, 67224632]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 11, 'section': 9}, 1, 5752388]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 7, 'section': 8}, 1, 71419895]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 6}, 1, 94911780]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 10, 'section': 19}, 1, 35655923]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 17, 'section': 17}, 2, 59129182]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 3, 'section': 5}, 1, 88193328]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 11, 'section': 17}, 1, 44190408]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 9, 'section': 19}, 1, 27038069]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 3}, 1, 58803673]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 2}, 2, 20439990]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 15, 'section': 10}, 3, 76217682]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 17, 'section': 20}, 1, 42756985]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 4, 'section': 19}, 1, 15581599]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 2}, 1, 34406583]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 15, 'section': 12}, 3, 66033624]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 8, 'section': 4}, 1, 23592733]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 8, 'section': 12}, 2, 16215938]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 8, 'section': 16}, 2, 4677220]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 16, 'section': 13}, 6, 28235691]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 2, 'section': 14}, 2, 95378686]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 12, 'section': 20}, 4, 86028625]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 1, 'section': 15}, 1, 34486151]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 20, 'section': 5}, 2, 70012905]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 1}, 1, 21706181]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 2}, 1, 70271356]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 4}, 2, 88134788]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 9, 'section': 15}, 9, 70068215]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 17, 'section': 15}, 5, 3435835]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 17, 'section': 17}, 1, 86597807]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 14, 'section': 16}, 3, 27127685]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 14, 'section': 6}, 1, 69204184]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 14, 'section': 9}, 1, 61946784]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 4, 'section': 15}, 3, 64596561]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 4, 'section': 19}, 1, 19235732]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 11, 'section': 7}, 1, 81176805]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 11, 'section': 6}, 6, 82634601]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 3}, 2, 23009293]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 9}, 1, 72723433]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 19}, 7, 79454592]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 18, 'section': 19}, 1, 79454592]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 7}, 3, 10778198]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 1}, 10, 67224632]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 3, 'section': 6}, 18, 92540665]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 18, 'section': 17}, 1, 65388645]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 18, 'section': 7}, 2, 64336191]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 15, 'section': 5}, 2, 42138962]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 16, 'section': 11}, 2, 9825360]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 16, 'section': 1}, 1, 12361451]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 19, 'section': 12}, 2, 69558272]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 6, 'section': 8}, 3, 53527758]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 13, 'section': 7}, 5, 89992783]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 13, 'section': 10}, 1, 64787177]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 5, 'section': 5}, 1, 80258939]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 20, 'section': 13}, 1, 76827955]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 20, 'section': 1}, 3, 60130574]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 2, 'section': 11}, 2, 72657454]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 2, 'section': 5}, 5, 94458446]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 9}, 1, 44389563]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 12}, 1, 56918577]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 9}, 1, 90631900]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 19, 'section': 4}, 1, 35655923]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 5}, 3, 9905776]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 5, 'section': 3}, 1, 88424842]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 10}, 1, 14121456]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 15, 'section': 4}, 1, 29644244]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 12, 'section': 6}, 1, 98763547]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 9}, 1, 67477573]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 20}, 3, 39420122]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 8, 'section': 17}, 5, 68542596]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 7, 'section': 10}, 1, 52516847]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 18, 'section': 9}, 4, 65538728]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 16, 'section': 3}, 1, 41772834]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 2, 'section': 8}, 2, 47367583]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 7, 'section': 20}, 1, 88906902]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 13, 'section': 4}, 5, 44986521]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 13, 'section': 1}, 1, 39163752]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 6, 'section': 8}, 1, 5143783]
# [{'block_x': 1, 'block_y': 2, 'floor': 1, 'row': 6, 'section': 3}, 1, 98878242]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 19, 'section': 14}, 2, 87515631]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 14, 'section': 1}, 5, 86959534]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 12, 'section': 2}, 2, 34406583]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 11, 'section': 15}, 2, 40210200]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 14, 'section': 7}, 2, 10556579]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 7, 'section': 5}, 2, 22492248]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 16, 'section': 11}, 16, 9825360]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 13, 'section': 20}, 2, 12287646]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 13, 'section': 11}, 2, 44068647]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 6, 'section': 13}, 2, 82850554]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 14}, 4, 41018725]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 2}, 5, 93783328]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 5, 'section': 1}, 1, 7515149]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 18, 'section': 1}, 1, 25143178]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 5}, 1, 44935756]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 12, 'section': 7}, 1, 72545784]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 15, 'section': 5}, 2, 42138962]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 14, 'section': 14}, 1, 15172277]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 6, 'section': 14}, 2, 82408055]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 20, 'section': 10}, 2, 15395811]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 12, 'section': 8}, 1, 7610952]
# [{'block_x': 1, 'block_y': 2, 'floor': 3, 'row': 10, 'section': 9}, 1, 15900724]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 6, 'section': 20}, 1, 95783540]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 6, 'section': 15}, 1, 6429545]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 20, 'section': 17}, 3, 75064794]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 10, 'section': 19}, 2, 35655923]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 5, 'section': 20}, 25, 63775860]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 5, 'section': 20}, 3, 63775860]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 13, 'section': 6}, 1, 94594045]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 13, 'section': 8}, 1, 40174200]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 13, 'section': 16}, 1, 59172561]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 7, 'section': 19}, 1, 35691023]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 2, 'section': 12}, 1, 90631900]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 9, 'section': 18}, 1, 68372304]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 4, 'section': 12}, 1, 28944660]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 3, 'section': 6}, 3, 60802704]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 3, 'section': 5}, 3, 88193328]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 3, 'section': 10}, 2, 73035776]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 11, 'section': 17}, 1, 5862186]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 17, 'section': 14}, 1, 63346154]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 17, 'section': 17}, 1, 59129182]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 19, 'section': 18}, 2, 13077716]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 19, 'section': 8}, 4, 38081639]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 4}, 5, 84063524]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 16, 'section': 20}, 1, 32476979]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 7, 'section': 12}, 5, 68505658]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 17}, 1, 52791441]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 7}, 1, 49138774]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 1}, 2, 67622656]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 11, 'section': 9}, 1, 5752388]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 20, 'section': 1}, 3, 60130574]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 4}, 1, 84063524]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 9}, 2, 15414161]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 14}, 1, 36857268]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 3}, 3, 94948127]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 12, 'section': 2}, 1, 28180626]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 15, 'section': 8}, 1, 46143732]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 15, 'section': 6}, 1, 76095430]
# [{'block_x': 1, 'block_y': 2, 'floor': 4, 'row': 5, 'section': 4}, 4, 92458788]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 18, 'section': 14}, 21, 15308813]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 13, 'section': 20}, 1, 5146455]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 13, 'section': 12}, 1, 6720892]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 1, 'section': 19}, 1, 50001986]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 9, 'section': 17}, 1, 37364473]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 14, 'section': 12}, 2, 11458449]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 8, 'section': 7}, 2, 1310384]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 6}, 1, 42943758]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 9}, 2, 59273565]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 10}, 2, 14121456]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 12}, 1, 74239677]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 20}, 5, 39420122]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 9}, 19, 67477573]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 2, 'section': 8}, 5, 47367583]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 2, 'section': 8}, 4, 47367583]
# [{'block_x': 1, 'block_y': 1, 'floor': 2, 'row': 17, 'section': 20}, 1, 42756985]
# [{'block_x': 1, 'block_y': 2, 'floor': 2, 'row': 15, 'section': 13}, 1, 83660065]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 16, 'section': 19}, 1, 67832065]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 16, 'section': 11}, 2, 9825360]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 4, 'section': 14}, 1, 71827305]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 17, 'section': 9}, 1, 5639589]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 18, 'section': 1}, 5, 25143178]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 2, 'section': 9}, 1, 77782066]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 1}, 1, 59273565]
# [{'block_x': 1, 'block_y': 1, 'floor': 3, 'row': 20, 'section': 3}, 1, 55695583]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 18, 'section': 15}, 1, 37832728]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 12, 'section': 13}, 3, 19823829]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 7, 'section': 15}, 3, 20743241]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 7, 'section': 14}, 2, 68505658]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 11, 'section': 14}, 2, 8607062]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 16, 'section': 12}, 1, 65603148]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 1, 'section': 12}, 1, 19545344]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 2, 'section': 11}, 2, 72657454]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 8, 'section': 9}, 7, 89968141]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 6, 'section': 1}, 5, 67622656]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 10, 'section': 9}, 1, 52230841]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 10, 'section': 15}, 1, 76072646]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 13, 'section': 15}, 3, 81786000]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 14, 'section': 11}, 1, 98822490]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 14, 'section': 9}, 1, 92135801]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 14, 'section': 8}, 2, 50519630]
# [{'block_x': 1, 'block_y': 1, 'floor': 4, 'row': 4, 'section': 6}, 1, 94911780]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 17, 'section': 6}, 1, 42943758]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 5, 'section': 20}, 3, 39420122]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 7, 'section': 5}, 1, 88404297]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 19, 'section': 2}, 3, 12230318]
# [{'block_x': 1, 'block_y': 1, 'floor': 1, 'row': 1, 'section': 1}, 1, 49110413]
